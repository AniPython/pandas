# %%
import pandas as pd

# %%
s = pd.Series(
    {'A': 1, 'B': 2, 'C': 3}
)
s
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
df = pd.DataFrame({
    'A': [1, 4, 7],
    'B': [2, 5, 8],
    'C': [3, 6, 9],
}, index=list('XYZ'))
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.to_numpy().sum()
# Out:
# 45

# %%
s['C']
# Out:
# 3

# %%
s.get('D', 888)
# Out:
# 888

# %%
df['B']
# Out:
# X    2
# Y    5
# Z    8
# Name: B, dtype: int64

# %%
s[2]
# Out:
# 3

# %%
# df[2] error

# %%
s[['B', 'C']]
# Out:
# B    2
# C    3
# dtype: int64

# %%
df[['B']]
# Out:
#    B
# X  2
# Y  5
# Z  8

# %%
s[[True, False, True]]
# Out:
# A    1
# C    3
# dtype: int64

# %%
df[[True, False, True]]
# Out:
#    A  B  C
# X  1  2  3
# Z  7  8  9

# %%
mask = s > 1
mask
# Out:
# A    False
# B     True
# C     True
# dtype: bool

# %%
s[s > 1]
# Out:
# B    2
# C    3
# dtype: int64

# %%
df['B'] > 2
# Out:
# X    False
# Y     True
# Z     True
# Name: B, dtype: bool

# %%
df[df['B'] > 2]
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
df[(df['B'] > 2) & (df['B'] < 6)]
# Out:
#    A  B  C
# Y  4  5  6

# %%
df[(df['B'] == 2) | (df['B'] == 8)]
# Out:
#    A  B  C
# X  1  2  3
# Z  7  8  9

# %%
df[~(df['B'] == 2)]
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
s = pd.Series([1, 2, 'a'])
s = s.replace('\w+', pd.NA, regex=True)
s = s[s.notna()]
s
# Out:
# 0    1
# 1    2
# dtype: object

# %%
import re
s = pd.Series([1, 2, 'a'])
s = s.astype('str')
mask = s.apply(lambda x: bool(re.match('\d+', x)))
s = s[mask]
s
# Out:
# 0    1
# 1    2
# dtype: object

# %%
def fun(x):
    try:
        return int(x)
    except:
        return pd.NA
s = pd.Series([1, 2, 'a'])
s = s.apply(fun).dropna()
s
# Out:
# 0    1
# 1    2
# dtype: object

# %%
s = pd.Series([1, 2, 'a'])
pd.Series(filter(lambda x: isinstance(x, int), s))
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
open('/Users/Yi/Mirror/我的python教程/Pandas办公自动化/B006_rw_pickle/2019.xlsx').read()
# Out:
# b'PK\x03\x04\n\x00\x00\x00\x00\x00\x87N\xe2@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00docProps/PK\x03\x04\x14\x00\x00\x00\x08\x00\x87N\xe2@\xceB\\\x011\x01\x00\x009\x02\x00\x00\x10\x00\x00\x00docProps/app.xml\x9d\x91\xc1J\x031\x10\x86\xef\x82\xef\x10r\xafi\x8b\x88\x94l\x8a\xa0\xe2E,X\xbd\xc7\xecl\x1b\xd8MBf\\Z\x9f\xc5\x8b\x07\xc17\xf0\xe4\xdb(\xf8\x18f7\xa0[\xf1\xe4m&\xff\xcf?\xdfO\xe4|\xd3\xd4\xac\x85\x88\xd6\xbb\x82O\x0e\xc6\x9c\x813\xbe\xb4nU\xf0\x9b\xe5\xf9\xe8\x983$\xedJ]{\x07\x05\xdf\x02\xf2\xb9\xda\xdf\x93\x8b\xe8\x03D\xb2\x80,E8,\xf8\x9a(\xcc\x84@\xb3\x86F\xe3A\x92]R*\x1f\x1bMi\x8d+\xe1\xab\xca\x1a8\xf5\xe6\xbe\x01Gb:\x1e\x1f\t\xd8\x10\xb8\x12\xcaQ\xf8\x0e\xe49q\xd6\xd2\x7fCKo:>\xbc]nC\x02V\xf2$\x84\xda\x1aM\xa9\xa5\xba\xb4&z\xf4\x15\xb1\xb3\x8d\x81Z\x8a\xa1(/@w\xe5\x17\xdaFT\xb2\xa5Y\x0b\x86|dh\x1fR\xfd)gw\x1a\xa1\x8b-x\xab\xa3\xd5\x8eR|g\xcbK?\xd7\x01)\xaa\x8f\xd7\xe7\xf7\xb7\xc7\xcf\xa7\x17)\x92\x9e\xdf\xfaqh\x1d\xce\xf6PMzC\x1av\x8d]@\xe6H\xc2.\xe1\xd2R\rxU-t\xa4?\x80\'C\xe0\x9e!\xe3f\x9c\xeb5\x00\xe5\x9bC\xbe\xbeq\xba\xf4+[\xfc\xfc\xb9\xfa\x02PK\x03\x04\x14\x00\x00\x00\x08\x00\x87N\xe2@\x1aa\xc4\x920\x01\x00\x002\x02\x00\x00\x11\x00\x00\x00docProps/core.xml\x8d\x91AO\x840\x10\x85\xef&\xfe\x07\xd2;\xb4\x85\xcdfm\x80=h\xf6\xa4\x89\x89\x18\x8d\xb7\xa6\x9de\x89\xb44m\x95\xdd\x7fo\x81]\xc4\xe8\xc1c\xe7\xbd\xf9\xe6M\'\xdf\x1eU\x1b}\x82uM\xa7\x0bD\x13\x82"\xd0\xa2\x93\x8d\xae\x0b\xf4\\\xed\xe2\r\x8a\x9c\xe7Z\xf2\xb6\xd3P\xa0\x138\xb4-\xaf\xafra\x98\xe8,<\xda\xce\x80\xf5\r\xb8(\x90\xb4c\xc2\x14\xe8\xe0\xbda\x18;q\x00\xc5]\x12\x1c:\x88\xfb\xce*\xee\xc3\xd3\xd6\xd8p\xf1\xcek\xc0)!k\xac\xc0s\xc9=\xc7\x03063\x11\x9d\x91R\xccH\xf3a\xdb\x11 \x05\x86\x16\x14h\xef0M(\xfe\xf6z\xb0\xca\xfd\xd90*\x0b\xa7j\xfc\xc9\x84\x9d\xceq\x97l)&qv\x1f]3\x1b\xfb\xbeO\xfal\x8c\x11\xf2S\xfc\xfap\xff4\xae\x1a7z\xf8+\x01\xa8\xcc\xa5`\xc2\x02\xf7\x9d-\x87\xfd\xcd\xe9\xd8\xe6xQ\x0c\x861\xcf\xe4\x02\x19\x85\tl\xcasQ^\xb2\xdb\xbbj\x87\xca\x94\xa4$&iL\xd7\x15\xbda\xab\x94\x11\xf26\xb0~\xf4\x0f\x13\xa7\x82\n\xd7\xdb7\xff \xae\xe24\xab\xe8\x9a\xad6,\xa3\x0b\xe2\x05P\xe6\xf8\xd7\x95\xcb/PK\x03\x04\x14\x00\x00\x00\x08\x00\x87N\xe2@\x91\x9cB\x9c\xfe\x00\x00\x00~\x01\x00\x00\x13\x00\x00\x00docProps/custom.xml\x9d\x90\xcbN\xc30\x10\x00\xefH\xfc\x83\xe5\xbbc\xc7%\xb4\x89\x9cT$i/\x1c@\xa2\xf4\x1e9Nk)~\xc8v\x02\x11\xe2\xdfqU\x1ew\x8e\xabY\x8df\x97m\xdf\xd5\x08f\xe1\xbc4\xba\x84iB \x10\x9a\x9b^\xeaS\t_\x0f{\xb4\x81\xc0\x87N\xf7\xddh\xb4(\xe1"<\xdcV\xb77\xec\xd9\x19+\\\x90\xc2\x83\xa8\xd0\xbe\x84\xe7\x10l\x81\xb1\xe7g\xa1:\x9fD\xac#\x19\x8cS]\x88\xa3;a3\x0c\x92\x8b\xd6\xf0I\t\x1d0%\xe4\x1e\xf3\xc9\x07\xa3\x90\xfd\xd5\xc1\xab\xaf\x98\xc3\x7f\x95\xbd\xe1\x97:\x7f<,6\xe6V\xec[\xbe\x80A\x05\xd9\x97\xf0\xa3\xcd\x9a\xb6\xcdH\x86\xe8.oPJ\xd2\x1a\xe5\xab|\x8d\xc8\x86\x10Z\xd3f\x9f?\xec>!\xb0\x97e\n\x81\xeeT<\xfd\xf1\xe5)j\xfb\x89\x87z\x92c\x7f\x14.\xaa\xe7P\x8c\xf6\xcd\x07WQ\x92QD\x934\xa1\xc9\xea.]3\xfc\x87\x18\xfe)\xa8\x18\xbe\xa4]\x1fW}\x01PK\x03\x04\n\x00\x00\x00\x00\x00\x87N\xe2@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00xl/PK\x03\x04\n\x00\x00\x00\x00\x00\x87N\xe2@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00xl/worksheets/PK\x03\x04\x14\x00\x00\x00\x08\x00\x87N\xe2@\n)BA\xb7_\x11\x00\x97\x1aq\x00\x18\x00\x00\x00xl/worksheets/sheet1.xml\x94\xfd[\x93%\xcd\x8d$\x08\xbe\xaf\xc8\xfe\x87\x12\xbeOU\xc6=\xa2\xa5\xbbG6"\xbe\xb8dF\xae\x8c\xec\xec\xe5\x99\xc3bOS\xa6X\xac%\xd9\xdd3\xfb\xebW\xe1\x80\xfb\x01T\xd5-{^\x98\xfcL\x0f`pS\x07`j\xee\xe7\xc4\xbf\xff\x1f\xff\xf7?\xff\xcb?\xfc\xd7?\xfe\xf5o\x7f\xfa\xcb\xbf\xfe\x87\xdf]\xfd\xe3\xb7\xdf\xfd\xc3\x1f\xff\xf5\x0f\x7f\xf9\xe7?\xfd\xeb\xff\xfa\x1f~\xf7\xff\xfa\x7f\xbe\xfd\x0f\x8f\xbf\xfb\x87\xbf\xfd\xfd\xf7\xff\xfa\xcf\xbf\xff\x97\xbf\xfc\xeb\x1f\xff\xc3\xef\xfe\x8f?\xfe\xedw\xff\xe3\x7f\xfc\xbf\xfe_\xfe\xfd\x7f\xfb\xcb_\xff\xb7\xbf\xfd\xe7?\xfe\xf1\xef\xff\x00\x0f\xff\xfa\xb7\xff\xf0\xbb\xff\xfc\xf7\xbf\xff\xdb\xbf\xfb\xa7\x7f\xfa\xdb\x1f\xfe\xf3\x1f\xff\xfc\xfb\xbf\xfd\xe3 ...
