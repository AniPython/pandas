# %% [markdown]
# #### distribution 单变量分布图
# - seaborn.distplot(): axes-level
# 1.hist
# 2.kde
# 3.rug

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(
    context='talk',  # paper, notebook, talk, poster
    style='darkgrid',  # darkgrid, whitegrid, dark, white, ticks
    palette='muted',  # deep,muted,bright,pastel,dark,colorblind,hls,husl,cm
    rc={
        'figure.figsize': [8, 6]
    }
)

# %%
df1 = pd.read_csv('./input/athlete_events.csv')
df2 = pd.read_csv('./input/noc_regions.csv')
df = pd.merge(
    df1, df2,
    on='NOC',
    how='left',
    validate='m:1')

# %%
df = df.query('Year>=1984')
df.drop_duplicates(['ID', 'Games'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148480 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      148480 non-null  int64
#  1   Name    148480 non-null  object
#  2   Sex     148480 non-null  object
#  3   Age     148095 non-null  float64
#  4   Height  140921 non-null  float64
#  5   Weight  140486 non-null  float64
#  6   Team    148480 non-null  object
#  7   NOC     148480 non-null  object
#  8   Games   148480 non-null  object
#  9   Year    148480 non-null  int64
#  10  Season  148480 non-null  object
#  11  City    148480 non-null  object
#  12  Sport   148480 non-null  object
#  13  Event   148480 non-null  object
#  14  Medal   20324 non-null   object
#  15  region  148199 non-null  object
#  16  notes   2228 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 20.4+ MB

# %%
sns.distplot(
    a=df['Weight'],
    bins=None,
    hist=True,
    kde=True, 
    rug=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\1849913170.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
plt.figure(figsize=(18, 6))
ax = sns.distplot(
    a=df['Weight'],
    bins=None,
    hist=True,
    kde=False)
ax.xaxis.set_major_locator(
    plt.MultipleLocator(5)
)
ax.tick_params(rotation=90,axis='x')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\1904703202.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(

# %%
plt.figure(figsize=(18, 6))
ax = sns.distplot(
    a=df['Weight'],
    bins=20,
    hist=True,
    kde=False)
ax.xaxis.set_major_locator(
    plt.MultipleLocator(5)
)
ax.tick_params(rotation=90,axis='x')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\174041521.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(

# %%
plt.figure(figsize=(18, 6))
ax = sns.distplot(
    a=df['Weight'],
    bins='doane',
    hist=True,
    kde=False)
ax.xaxis.set_major_locator(
    plt.MultipleLocator(5)
)
ax.tick_params(rotation=90,axis='x')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\2935834127.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(

# %%
plt.figure(figsize=(18, 6))
ax = sns.distplot(
    a=df['Weight'],
    bins='sturges',
    hist=True,
    kde=False)
ax.xaxis.set_major_locator(
    plt.MultipleLocator(5)
)
ax.tick_params(rotation=90,axis='x')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\226432826.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(

# %%
plt.figure(figsize=(18, 6))
ax = sns.distplot(
    a=df['Weight'],
    bins='stone',
    hist=True,
    kde=False)
ax.xaxis.set_major_locator(
    plt.MultipleLocator(5)
)
ax.tick_params(rotation=90,axis='x')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9584\1617219393.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(
# D:\venv\py312\Lib\site-packages\numpy\lib\_histograms_impl.py:790: RuntimeWarning: The number of bins estimated may be suboptimal.
#   bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
