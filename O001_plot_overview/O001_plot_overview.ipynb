# %%
import pandas as pd
import seaborn as sns

# %%
sns.set_style('white')

# %%
s = pd.Series(
    [1,3,2],
    index=list('ABC'))
s
# Out:
# A    1
# B    3
# C    2
# dtype: int64

# %%
s.plot()

# %%
s.plot(kind='line')

# %%
s.plot.line()

# %%
s.plot?
