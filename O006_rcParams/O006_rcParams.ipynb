# %%
# https://matplotlib.org/tutorials/introductory/customizing.html#matplotlibrc-sample
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif']=['Hiragino Sans GB']  # win: ['SimHei']
plt.rcParams['figure.facecolor'] = 'y'
plt.rcParams['axes.facecolor'] = (0.8, 0.9, 0.8)
plt.rcParams['axes.titlesize'] = 36
plt.rcParams['axes.labelsize'] = 30
plt.rcParams['xtick.labelsize'] = 24
plt.rcParams['ytick.labelsize'] = 'large'
plt.rcParams['lines.linewidth'] = 3
plt.rcParams['lines.linestyle'] = '--'

# %%
x = np.array([1, 2, 3])
y2 = x ** 2
y4 = x ** 4

# %%
plt.plot(x, y2, label='2')
plt.plot(x, y4, label='4')

plt.title('我是标题')
plt.xlabel('X轴')
plt.ylabel('Y轴')

plt.legend()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# D:\venv\py312\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 36724 (\N{CJK UNIFIED IDEOGRAPH-8F74}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
_, axs = plt.subplots(
    2, 1,
    figsize=(6, 8))
axs[0].plot(x, y2, label='2')
axs[0].set_title('我是平方')
axs[0].set_xlabel('X轴')
axs[0].set_ylabel('Y轴')

axs[1].plot(x, y4, label='4')
axs[1].set_title('我是四次方')
axs[1].set_xlabel('X轴')
axs[1].set_ylabel('Y轴')

plt.tight_layout()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Hiragino Sans GB
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10488\1826931211.py:14: UserWarning: Glyph 36724 (\N{CJK UNIFIED IDEOGRAPH-8F74}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...
